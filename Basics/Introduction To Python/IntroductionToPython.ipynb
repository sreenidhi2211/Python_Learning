# %% [markdown]
# #Hello, World!

# %%
# Write a script that prints the phrase: Hello, World!
print("Hello,World!")
# Out:
# Hello,World!

# %% [markdown]
# # Your First Name

# %%
# Write a Python script to print your first name to the screen.
print("First name")
# Out:
# First name

# %% [markdown]
# # Comment

# %%
# Add a comment above your print statement explaining what the code does.
#this statement prints my pet name
print("Berry")
# Out:
# Berry

# %% [markdown]
# # print without Quotations

# %%
# Try printing a number (e.g., 2024) without using quotation marks. Does it work?
print(2024)
# Out:
# 2024

# %% [markdown]
# # String without Quotations
# observations:
# * when we tried to print a string without "" the error is thrown and it is:
# * Name Error: name "String you want to display" not defined

# %%
# Try printing a word without quotation marks. What error do you get?
print(Hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11151/2476178235.py in <cell line: 0>()
#       1 # Try printing a word without quotation marks. What error do you get?
# ----> 2 print(Hello)
#
# NameError: name 'Hello' is not defined

# %% [markdown]
# # Printing Multiple lines

# %%
# Write a program that prints three different lines of text using three separate print() functions.
print("Hiii")
print(2026)
print(True)
# Out:
# Hiii
# 2026
# True

# %% [markdown]
# # Identation
# Observations:
#
#
# *When a space is added before the print an error is thrown and it is:
# * IndentationError: unexpected indent

# %%
#Put a space before a print statement where there shouldn't be one) and observe the error Python gives you.
# print(456) # try by removing the comment for this line
# since it throws a warning for next line if nnot commented

# %% [markdown]
# # String with Apostrophe

# %%
print("hey I 'm a student")
# Out:
# hey I 'm a student

# %% [markdown]
# # String with Qutotation

# %%
# How would you print a sentence that literally includes quotation marks inside the output?
print("Hello I am 'Happy' and you are") # single quote inside double quote
print('Hello I am "Happy" and you are') # double quote inside single quote
print("""Hello I am "Happy " 'Day' and you are """) # any types of quotes inside triple quotes
# Out:
# Hello I am 'Happy' and you are
# Hello I am "Happy" and you are
# Hello I am "Happy " 'Day' and you are

# %% [markdown]
# # A blank line in Between

# %%
# Write a script that prints a blank line between two sentences.
print("Hello")
print()
print("Google")
# Out:
# Hello
#
# Google

# %% [markdown]
# # Comment after print

# %%
# Try placing a comment at the very end of a line of code (after a print statement). Does the code still run?
print("What are you doing")#it is a followup comment
# Out:
# What are you doing

# %% [markdown]
# # Commas and print statement

# %%
# print multiple words separated by commas in a single print() function
print("Hi,Hello,Namaste")# even though seperated by commas they are still in one "" so it is considered as one string only
print("Hi ,Hello,")
print("hi","hello")# sperate " " hence space between them
# Out:
# Hi,Hello,Namaste
# Hi ,Hello,
# hi hello
